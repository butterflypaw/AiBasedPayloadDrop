# %%
import cv2
import time
import torch
import socket
import struct
import numpy as np
from utils.general import non_max_suppression, scale_coords
from utils.torch_utils import select_device
from datetime import datetime

# %%
# Load pre-trained YOLOv7 model and set device
device = select_device('0' if torch.cuda.is_available() else 'cpu')
print(device)
model = torch.load('yolov7.pt', map_location=device)['model']
model.eval()
# Out:
# cuda:0
# C:\Users\kolak\AppData\Local\Temp\ipykernel_19052\3291274807.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load('yolov7.pt', map_location=device)['model']
# Model(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (1): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (2): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (3): Conv(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (4): Conv(
#       (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (5): Conv(
#       (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (6): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (7): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (8): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (9): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (10): Concat()
#     (11): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (12): MP(
#       (m): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (13): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (14): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (15): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (16): Concat()
#     (17): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (18): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (19): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (20): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (21): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (22): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (23): Concat()
#     (24): Conv(
#       (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (25): MP(
#       (m): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (26): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (27): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (28): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (29): Concat()
#     (30): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (31): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (32): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (33): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (34): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (35): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (36): Concat()
#     (37): Conv(
#       (conv): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(1024, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (38): MP(
#       (m): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (39): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (40): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (41): Conv(
#       (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (42): Concat()
#     (43): Conv(
#       (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (44): Conv(
#       (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (45): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (46): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (47): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (48): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (49): Concat()
#     (50): Conv(
#       (conv): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(1024, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (51): SPPCSPC(
#       (cv1): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (cv2): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (cv3): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (cv4): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (m): ModuleList(
#         (0): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (1): MaxPool2d(kernel_size=9, stride=1, padding=4, dilation=1, ceil_mode=False)
#         (2): MaxPool2d(kernel_size=13, stride=1, padding=6, dilation=1, ceil_mode=False)
#       )
#       (cv5): Conv(
#         (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (cv6): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (cv7): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#     )
#     (52): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (53): Upsample(scale_factor=2.0, mode='nearest')
#     (54): Conv(
#       (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (55): Concat()
#     (56): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (57): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (58): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (59): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (60): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (61): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (62): Concat()
#     (63): Conv(
#       (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (64): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (65): Upsample(scale_factor=2.0, mode='nearest')
#     (66): Conv(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (67): Concat()
#     (68): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (69): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (70): Conv(
#       (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (71): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (72): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (73): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (74): Concat()
#     (75): Conv(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (76): MP(
#       (m): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (77): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (78): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (79): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (80): Concat()
#     (81): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (82): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (83): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (84): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (85): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (86): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (87): Concat()
#     (88): Conv(
#       (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (89): MP(
#       (m): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (90): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (91): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (92): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (93): Concat()
#     (94): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (95): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (96): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (97): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (98): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (99): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (100): Concat()
#     (101): Conv(
#       (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (102): RepConv(
#       (act): SiLU()
#       (rbr_dense): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       )
#       (rbr_1x1): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       )
#     )
#     (103): RepConv(
#       (act): SiLU()
#       (rbr_dense): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       )
#       (rbr_1x1): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       )
#     )
#     (104): RepConv(
#       (act): SiLU()
#       (rbr_dense): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       )
#       (rbr_1x1): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       )
#     )
#     (105): Detect(
#       (m): ModuleList(
#         (0): Conv2d(256, 255, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 255, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 255, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
# )

# %%
def preprocess_image(img, img_size=640):
    # Get original image dimensions
    h, w = img.shape[:2]
    
    # Calculate the resize ratio while keeping aspect ratio
    scale = min(img_size / h, img_size / w)
    
    # Calculate new dimensions
    new_w, new_h = int(w * scale), int(h * scale)
    
    # Resize image
    img_resized = cv2.resize(img, (new_w, new_h))  # Resize keeping aspect ratio
    
    # Padding to fit img_size if needed (to make the image square)
    top_pad = (img_size - new_h) // 2
    bottom_pad = img_size - new_h - top_pad
    left_pad = (img_size - new_w) // 2
    right_pad = img_size - new_w - left_pad
    
    # Pad the resized image with zeros (black pixels)
    img_resized = cv2.copyMakeBorder(img_resized, top_pad, bottom_pad, left_pad, right_pad, cv2.BORDER_CONSTANT, value=(0, 0, 0))
    
    # Convert BGR to RGB and HWC to CHW format for PyTorch
    img_resized = img_resized[:, :, ::-1].transpose(2, 0, 1)
    img_resized = np.ascontiguousarray(img_resized)
    
    # Normalize to 0-1
    img_resized = torch.from_numpy(img_resized).float() / 255.0
    
    # Add batch dimension
    if img_resized.ndimension() == 3:
        img_resized = img_resized.unsqueeze(0)

    return img_resized

# %%
def detect_humans(image, model, device, img_size=640, conf_thresh=0.25, iou_thresh=0.45):
    # Preprocess image
    img_preprocessed = preprocess_image(image, img_size).to(device)
    
    # Check if the model is using half precision and adjust input
    if next(model.parameters()).dtype == torch.float16:
        img_preprocessed = img_preprocessed.half()  # Convert image to half precision

    with torch.no_grad():
        pred = model(img_preprocessed)[0]  # Run inference
    
    # Apply non-max suppression to filter out multiple detections
    pred = non_max_suppression(pred, conf_thresh, iou_thresh, classes=[0])  # Class 0 is humans
    
    return pred

# %%
def plot_detections(image, predictions, img_size=640):
    img_copy = image.copy()
    h, w = img_copy.shape[:2]  # Get original image dimensions

    for det in predictions:
        if len(det):
            # Convert from normalized coordinates back to original image coordinates
            det[:, :4] = scale_coords((img_size, img_size), det[:, :4], img_copy.shape).round()
            for *xyxy, conf, cls in det:
                # Draw bounding box
                cv2.rectangle(img_copy, (int(xyxy[0]), int(xyxy[1])), (int(xyxy[2]), int(xyxy[3])), (255, 0, 0), 2)
                cv2.putText(img_copy, f'Person {conf:.2f}', (int(xyxy[0]), int(xyxy[1]) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)

    return img_copy

# %%
# Function to calculate the center of a bounding box
def calculate_bbox_center(x1, y1, x2, y2):
    center_x = (x1 + x2) // 2
    center_y = (y1 + y2) // 2
    return center_x, center_y

def calculate_direction(center_x, center_y, frame_center_x, frame_center_y, x1, y1, x2, y2):
    instructions = []

    # Check if the frame center lies inside the bounding box
    if x1 <= frame_center_x <= x2 and y1 <= frame_center_y <= y2:
        instructions.append("Centered")
    else:
        # Horizontal adjustment
        if frame_center_x < x1:
            instructions.append("Move Right")
        elif frame_center_x > x2:
            instructions.append("Move Left")

        # Forward/Backward adjustment
        if frame_center_y < y1:
            instructions.append("Move Forward")
        elif frame_center_y > y2:
            instructions.append("Move Backward")

    return ", ".join(instructions)

# %%
# Capture video feed from the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open video source.")
    exit()

# %%
# Process the video feed frame by frame
while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Failed to capture image.")
        break

    # Get the dimensions of the frame
    frame_height, frame_width = frame.shape[:2]
    frame_center_x = frame_width // 2
    frame_center_y = frame_height // 2

    # Run human detection on the current frame
    predictions = detect_humans(frame, model, device)

    num_people = 0
    closest_person = None
    closest_distance = float('inf')

    for det in predictions:
        for *xyxy, conf, cls in det:
            if conf.item() >= 0.5:
                num_people += 1

                # Extract bounding box coordinates
                x1, y1, x2, y2 = map(int, xyxy)

                # Calculate bounding box center
                bbox_center_x, bbox_center_y = calculate_bbox_center(x1, y1, x2, y2)

                # Calculate distance from frame center to bounding box center
                distance = ((bbox_center_x - frame_center_x) ** 2 + (bbox_center_y - frame_center_y) ** 2) ** 0.5

                # Update closest person if necessary
                if distance < closest_distance:
                    closest_distance = distance
                    closest_person = (bbox_center_x, bbox_center_y, x1, y1, x2, y2)
    print(num_people)
    if closest_person:
        bbox_center_x, bbox_center_y, x1, y1, x2, y2 = closest_person
        direction = calculate_direction(bbox_center_x, bbox_center_y, frame_center_x, frame_center_y,x1,y1,x2,y2)
        print(f"Closest Person at ({bbox_center_x}, {bbox_center_y}): {direction}")
    else:
        print("No humans detected.")

    # Plot detections on the frame
    frame_with_detections = plot_detections(frame, predictions)

    # Display the frame with detections
    cv2.imshow('YOLOv7 Human Detection', frame_with_detections)

    # Exit loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("Exiting live feed")
        break

# Release the video capture and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 1
# Closest Person at (313, 365): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (312, 365): Centered
# 1
# Closest Person at (315, 365): Centered
# 1
# Closest Person at (316, 365): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (315, 365): Centered
# 1
# Closest Person at (312, 365): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (312, 365): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (312, 364): Centered
# 1
# Closest Person at (312, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (314, 365): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (314, 365): Centered
# 1
# Closest Person at (313, 365): Centered
# 1
# Closest Person at (314, 365): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (312, 365): Centered
# 1
# Closest Person at (313, 365): Centered
# 1
# Closest Person at (313, 365): Centered
# 1
# Closest Person at (312, 365): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (313, 365): Centered
# 1
# Closest Person at (313, 365): Centered
# 1
# Closest Person at (313, 365): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 365): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (315, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (315, 365): Centered
# 1
# Closest Person at (315, 365): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 365): Centered
# 1
# Closest Person at (314, 365): Centered
# 1
# Closest Person at (314, 365): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 365): Centered
# 1
# Closest Person at (312, 364): Centered
# 1
# Closest Person at (313, 365): Centered
# 1
# Closest Person at (312, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (312, 365): Centered
# 1
# Closest Person at (313, 365): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (313, 365): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (313, 365): Centered
# 1
# Closest Person at (312, 365): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 365): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (315, 364): Centered
# 1
# Closest Person at (313, 365): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (315, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 365): Centered
# 1
# Closest Person at (314, 365): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (312, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (314, 365): Centered
# 1
# Closest Person at (314, 365): Centered
# 1
# Closest Person at (314, 365): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (315, 364): Centered
# 1
# Closest Person at (315, 365): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (315, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (315, 365): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 365): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (313, 365): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (313, 365): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (312, 365): Centered
# 1
# Closest Person at (312, 365): Centered
# 1
# Closest Person at (312, 365): Centered
# 1
# Closest Person at (312, 365): Centered
# 1
# Closest Person at (311, 365): Centered
# 1
# Closest Person at (312, 364): Centered
# 1
# Closest Person at (314, 365): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (312, 364): Centered
# 1
# Closest Person at (312, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (315, 364): Centered
# 1
# Closest Person at (314, 365): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (315, 364): Centered
# 1
# Closest Person at (315, 365): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (316, 365): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (316, 365): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (316, 365): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (316, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (316, 365): Centered
# 1
# Closest Person at (315, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (317, 365): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (316, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (316, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (316, 364): Centered
# 1
# Closest Person at (317, 365): Centered
# 1
# Closest Person at (316, 365): Centered
# 1
# Closest Person at (317, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (316, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (316, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (316, 365): Centered
# 1
# Closest Person at (316, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (317, 364): Centered
# 1
# Closest Person at (316, 365): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (316, 365): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (316, 365): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (316, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (317, 364): Centered
# 1
# Closest Person at (316, 364): Centered
# 1
# Closest Person at (317, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (319, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (316, 364): Centered
# 1
# Closest Person at (318, 363): Centered
# 1
# Closest Person at (316, 365): Centered
# 1
# Closest Person at (316, 364): Centered
# 1
# Closest Person at (317, 365): Centered
# 1
# Closest Person at (316, 365): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (316, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (317, 364): Centered
# 1
# Closest Person at (315, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (314, 364): Centered
# 1
# Closest Person at (315, 364): Centered
# 1
# Closest Person at (315, 365): Centered
# 1
# Closest Person at (317, 364): Centered
# 1
# Closest Person at (317, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (317, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (317, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (317, 364): Centered
# 1
# Closest Person at (315, 364): Centered
# 1
# Closest Person at (315, 365): Centered
# 1
# Closest Person at (315, 364): Centered
# 1
# Closest Person at (315, 364): Centered
# 1
# Closest Person at (315, 365): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (318, 364): Centered
# 1
# Closest Person at (313, 364): Centered
# 1
# Closest Person at (311, 364): Centered
# 1
# Closest Person at (312, 364): Centered
# 1
# Closest Person at (312, 364): Centered
# 1
# Closest Person at (311, 365): Centered
# 1
# Closest Person at (311, 364): Centered
# 1
# Closest Person at (312, 364): Centered
# 1
# Closest Person at (310, 364): Centered
# 1
# Closest Person at (309, 364): Centered
# 1
# Closest Person at (304, 365): Centered
# 1
# Closest Person at (302, 364): Centered
# 1
# Closest Person at (299, 363): Centered
# 1
# Closest Person at (299, 363): Centered
# 1
# Closest Person at (295, 364): Centered
# 1
# Closest Person at (297, 364): Centered
# 1
# Closest Person at (294, 364): Centered
# 1
# Closest Person at (280, 364): Centered
# 1
# Closest Person at (278, 365): Centered
# 1
# Closest Person at (278, 364): Centered
# 1
# Closest Person at (269, 364): Centered
# 1
# Closest Person at (270, 363): Centered
# 1
# Closest Person at (268, 363): Centered
# 1
# Closest Person at (266, 363): Centered
# 1
# Closest Person at (265, 363): Centered
# 1
# Closest Person at (258, 363): Centered
# 1
# Closest Person at (255, 363): Centered
# 1
# Closest Person at (258, 362): Centered
# 1
# Closest Person at (256, 362): Centered
# 1
# Closest Person at (254, 363): Centered
# 1
# Closest Person at (253, 363): Centered
# 1
# Closest Person at (251, 362): Centered
# 1
# Closest Person at (249, 363): Centered
# 1
# Closest Person at (243, 362): Centered
# 1
# Closest Person at (245, 362): Centered
# 1
# Closest Person at (243, 362): Centered
# 1
# Closest Person at (241, 362): Centered
# 1
# Closest Person at (241, 360): Centered
# 1
# Closest Person at (241, 361): Centered
# 1
# Closest Person at (239, 361): Centered
# 1
# Closest Person at (237, 360): Centered
# 1
# Closest Person at (236, 360): Centered
# 1
# Closest Person at (235, 360): Centered
# 1
# Closest Person at (237, 361): Centered
# 1
# Closest Person at (235, 361): Centered
# 1
# Closest Person at (234, 361): Centered
# 1
# Closest Person at (233, 360): Centered
# 1
# Closest Person at (233, 360): Centered
# 1
# Closest Person at (230, 359): Centered
# 1
# Closest Person at (229, 359): Centered
# 1
# Closest Person at (227, 359): Centered
# 1
# Closest Person at (227, 359): Centered
# 1
# Closest Person at (227, 358): Centered
# 1
# Closest Person at (226, 358): Centered
# 1
# Closest Person at (225, 359): Centered
# 1
# Closest Person at (223, 359): Centered
# 1
# Closest Person at (222, 358): Centered
# 1
# Closest Person at (220, 359): Centered
# 1
# Closest Person at (220, 358): Centered
# 1
# Closest Person at (219, 360): Centered
# 1
# Closest Person at (220, 357): Centered
# 1
# Closest Person at (219, 359): Centered
# 1
# Closest Person at (219, 358): Centered
# 1
# Closest Person at (219, 358): Centered
# 1
# Closest Person at (219, 358): Centered
# 1
# Closest Person at (220, 358): Centered
# 1
# Closest Person at (221, 359): Centered
# 1
# Closest Person at (221, 360): Centered
# 1
# Closest Person at (221, 358): Centered
# 1
# Closest Person at (221, 358): Centered
# 1
# Closest Person at (221, 359): Centered
# 1
# Closest Person at (221, 359): Centered
# 1
# Closest Person at (221, 358): Centered
# 1
# Closest Person at (221, 358): Centered
# 1
# Closest Person at (221, 359): Centered
# 1
# Closest Person at (221, 359): Centered
# 1
# Closest Person at (221, 358): Centered
# 1
# Closest Person at (221, 359): Centered
# 1
# Closest Person at (221, 359): Centered
# 1
# Closest Person at (221, 358): Centered
# 1
# Closest Person at (221, 359): Centered
# 1
# Closest Person at (221, 359): Centered
# 1
# Closest Person at (221, 358): Centered
# 1
# Closest Person at (215, 359): Centered
# 1
# Closest Person at (214, 360): Centered
# 1
# Closest Person at (212, 360): Centered
# 1
# Closest Person at (212, 359): Centered
# 1
# Closest Person at (212, 357): Centered
# 1
# Closest Person at (210, 356): Centered
# 1
# Closest Person at (209, 357): Centered
# 1
# Closest Person at (207, 360): Centered
# 1
# Closest Person at (207, 357): Centered
# 1
# Closest Person at (208, 355): Centered
# 1
# Closest Person at (206, 356): Centered
# 1
# Closest Person at (204, 357): Centered
# 1
# Closest Person at (202, 359): Centered
# 1
# Closest Person at (201, 359): Centered
# 1
# Closest Person at (198, 358): Centered
# 1
# Closest Person at (192, 358): Centered
# 1
# Closest Person at (196, 356): Centered
# 1
# Closest Person at (196, 355): Centered
# 1
# Closest Person at (196, 355): Centered
# 1
# Closest Person at (190, 357): Centered
# 1
# Closest Person at (189, 358): Centered
# 1
# Closest Person at (190, 356): Centered
# 1
# Closest Person at (189, 356): Centered
# 1
# Closest Person at (187, 353): Centered
# 1
# Closest Person at (187, 352): Centered
# 1
# Closest Person at (187, 355): Centered
# 1
# Closest Person at (187, 357): Centered
# 1
# Closest Person at (186, 352): Centered
# 1
# Closest Person at (188, 353): Centered
# 1
# Closest Person at (189, 353): Centered
# 1
# Closest Person at (188, 355): Centered
# 1
# Closest Person at (189, 355): Centered
# 1
# Closest Person at (189, 353): Centered
# 1
# Closest Person at (189, 353): Centered
# 1
# Closest Person at (188, 354): Centered
# 1
# Closest Person at (189, 354): Centered
# 1
# Closest Person at (189, 353): Centered
# 1
# Closest Person at (189, 353): Centered
# 1
# Closest Person at (189, 353): Centered
# 1
# Closest Person at (189, 354): Centered
# 1
# Closest Person at (189, 354): Centered
# 1
# Closest Person at (189, 353): Centered
# 1
# Closest Person at (189, 353): Centered
# 1
# Closest Person at (189, 354): Centered
# 1
# Closest Person at (189, 354): Centered
# 1
# Closest Person at (189, 354): Centered
# 1
# Closest Person at (189, 353): Centered
# 1
# Closest Person at (189, 355): Centered
# 1
# Closest Person at (189, 355): Centered
# 1
# Closest Person at (189, 355): Centered
# 1
# Closest Person at (189, 355): Centered
# 1
# Closest Person at (189, 354): Centered
# 1
# Closest Person at (189, 354): Centered
# 1
# Closest Person at (189, 355): Centered
# 1
# Closest Person at (188, 354): Centered
# 1
# Closest Person at (189, 356): Centered
# 1
# Closest Person at (188, 354): Centered
# 1
# Closest Person at (189, 354): Centered
# 1
# Closest Person at (188, 354): Centered
# 1
# Closest Person at (183, 354): Centered
# 1
# Closest Person at (183, 353): Centered
# 1
# Closest Person at (181, 353): Centered
# 1
# Closest Person at (180, 355): Centered
# 1
# Closest Person at (176, 355): Centered
# 1
# Closest Person at (179, 354): Centered
# 1
# Closest Person at (178, 352): Centered
# 1
# Closest Person at (177, 352): Centered
# 1
# Closest Person at (172, 351): Centered
# 1
# Closest Person at (173, 352): Centered
# 1
# Closest Person at (174, 353): Centered
# 1
# Closest Person at (172, 354): Centered
# 1
# Closest Person at (167, 353): Centered
# 1
# Closest Person at (166, 353): Centered
# 1
# Closest Person at (166, 353): Centered
# 1
# Closest Person at (168, 355): Centered
# 1
# Closest Person at (166, 354): Centered
# 1
# Closest Person at (168, 354): Centered
# 1
# Closest Person at (168, 353): Centered
# 1
# Closest Person at (169, 354): Centered
# 1
# Closest Person at (168, 354): Centered
# 1
# Closest Person at (168, 351): Centered
# 1
# Closest Person at (169, 352): Centered
# 1
# Closest Person at (169, 351): Centered
# 1
# Closest Person at (169, 351): Centered
# 1
# Closest Person at (169, 350): Centered
# 1
# Closest Person at (169, 350): Centered
# 1
# Closest Person at (169, 350): Centered
# 1
# Closest Person at (169, 351): Centered
# 1
# Closest Person at (169, 351): Centered
# 1
# Closest Person at (168, 351): Centered
# 1
# Closest Person at (169, 351): Centered
# 1
# Closest Person at (169, 350): Centered
# 1
# Closest Person at (169, 351): Centered
# 1
# Closest Person at (169, 351): Centered
# 1
# Closest Person at (169, 351): Centered
# 1
# Closest Person at (169, 351): Centered
# 1
# Closest Person at (169, 351): Centered
# 1
# Closest Person at (169, 350): Centered
# 1
# Closest Person at (169, 350): Centered
# 1
# Closest Person at (169, 351): Centered
# 1
# Closest Person at (169, 351): Centered
# 1
# Closest Person at (169, 350): Centered
# 1
# Closest Person at (168, 351): Centered
# 1
# Closest Person at (168, 351): Centered
# 1
# Closest Person at (169, 350): Centered
# 1
# Closest Person at (169, 350): Centered
# 1
# Closest Person at (168, 351): Centered
# 1
# Closest Person at (168, 350): Centered
# 1
# Closest Person at (167, 350): Centered
# 1
# Closest Person at (167, 351): Centered
# 1
# Closest Person at (168, 351): Centered
# 1
# Closest Person at (168, 350): Centered
# 1
# Closest Person at (167, 350): Centered
# 1
# Closest Person at (163, 353): Centered
# 1
# Closest Person at (162, 350): Centered
# 1
# Closest Person at (170, 351): Centered
# 1
# Closest Person at (181, 351): Centered
# 1
# Closest Person at (188, 350): Centered
# 1
# Closest Person at (200, 352): Centered
# 1
# Closest Person at (159, 349): Move Left
# 1
# Closest Person at (164, 351): Centered
# 1
# Closest Person at (168, 350): Centered
# 1
# Closest Person at (168, 350): Centered
# 1
# Closest Person at (168, 350): Centered
# 1
# Closest Person at (168, 349): Centered
# 1
# Closest Person at (168, 350): Centered
# 1
# Closest Person at (168, 350): Centered
# 1
# Closest Person at (168, 350): Centered
# 1
# Closest Person at (168, 350): Centered
# 1
# Closest Person at (168, 350): Centered
# 1
# Closest Person at (168, 351): Centered
# 1
# Closest Person at (169, 350): Centered
# 1
# Closest Person at (168, 350): Centered
# 1
# Closest Person at (168, 350): Centered
# 1
# Closest Person at (168, 350): Centered
# 1
# Closest Person at (168, 351): Centered
# 1
# Closest Person at (168, 351): Centered
# 1
# Closest Person at (164, 352): Centered
# 1
# Closest Person at (163, 349): Centered
# 1
# Closest Person at (161, 349): Centered
# 1
# Closest Person at (157, 350): Move Left
# 1
# Closest Person at (157, 350): Move Left
# 1
# Closest Person at (156, 349): Move Left
# 1
# Closest Person at (153, 352): Move Left
# 1
# Closest Person at (149, 351): Move Left
# 1
# Closest Person at (149, 350): Move Left
# 1
# Closest Person at (148, 349): Move Left
# 1
# Closest Person at (148, 349): Move Left
# 1
# Closest Person at (147, 349): Move Left
# 1
# Closest Person at (147, 349): Move Left
# 1
# Closest Person at (147, 349): Move Left
# 1
# Closest Person at (147, 348): Move Left
# 1
# Closest Person at (147, 348): Move Left
# 1
# Closest Person at (146, 349): Move Left
# 1
# Closest Person at (146, 348): Move Left
# 1
# Closest Person at (146, 348): Move Left
# 1
# Closest Person at (146, 349): Move Left
# 1
# Closest Person at (145, 349): Move Left
# 1
# Closest Person at (145, 349): Move Left
# 1
# Closest Person at (143, 350): Move Left
# 1
# Closest Person at (140, 350): Move Left
# 1
# Closest Person at (140, 350): Move Left
# 1
# Closest Person at (139, 349): Move Left
# 1
# Closest Person at (139, 349): Move Left
# 1
# Closest Person at (138, 349): Move Left
# 1
# Closest Person at (138, 349): Move Left
# 1
# Closest Person at (137, 349): Move Left
# 1
# Closest Person at (138, 349): Move Left
# 1
# Closest Person at (138, 350): Move Left
# 1
# Closest Person at (140, 350): Move Left
# 1
# Closest Person at (138, 349): Move Left
# 1
# Closest Person at (138, 349): Move Left
# 1
# Closest Person at (138, 350): Move Left
# 1
# Closest Person at (138, 350): Move Left
# 1
# Closest Person at (138, 350): Move Left
# 1
# Closest Person at (137, 349): Move Left
# 1
# Closest Person at (138, 350): Move Left
# 1
# Closest Person at (138, 350): Move Left
# 1
# Closest Person at (137, 349): Move Left
# 1
# Closest Person at (138, 350): Move Left
# 1
# Closest Person at (139, 350): Move Left
# 1
# Closest Person at (138, 350): Move Left
# 1
# Closest Person at (139, 349): Move Left
# 1
# Closest Person at (138, 349): Move Left
# 1
# Closest Person at (139, 349): Move Left
# 1
# Closest Person at (139, 349): Move Left
# 1
# Closest Person at (138, 350): Move Left
# 1
# Closest Person at (139, 349): Move Left
# 1
# Closest Person at (139, 350): Move Left
# 1
# Closest Person at (139, 350): Move Left
# 1
# Closest Person at (139, 349): Move Left
# 1
# Closest Person at (139, 349): Move Left
# 1
# Closest Person at (139, 350): Move Left
# 1
# Closest Person at (139, 349): Move Left
# 1
# Closest Person at (140, 350): Move Left
# 1
# Closest Person at (139, 349): Move Left
# 1
# Closest Person at (139, 350): Move Left
# 1
# Closest Person at (139, 350): Move Left
# 1
# Closest Person at (139, 350): Move Left
# 1
# Closest Person at (140, 350): Move Left
# 1
# Closest Person at (140, 350): Move Left
# 1
# Closest Person at (139, 350): Move Left
# 1
# Closest Person at (139, 349): Move Left
# 1
# Closest Person at (139, 350): Move Left
# 1
# Closest Person at (139, 349): Move Left
# 1
# Closest Person at (139, 350): Move Left
# 1
# Closest Person at (138, 350): Move Left
# 1
# Closest Person at (139, 349): Move Left
# 1
# Closest Person at (139, 350): Move Left
# 1
# Closest Person at (139, 350): Move Left
# 1
# Closest Person at (139, 350): Move Left
# 1
# Closest Person at (139, 350): Move Left
# 1
# Closest Person at (141, 350): Move Left
# 1
# Closest Person at (140, 351): Move Left
# 1
# Closest Person at (138, 350): Move Left
# 1
# Closest Person at (139, 353): Move Left
# 1
# Closest Person at (138, 359): Move Left
# 1
# Closest Person at (135, 363): Move Left
# 1
# Closest Person at (135, 367): Move Left
# 1
# Closest Person at (134, 371): Move Left
# 1
# Closest Person at (132, 373): Move Left
# 1
# Closest Person at (132, 374): Move Left
# 1
# Closest Person at (132, 375): Move Left
# 1
# Closest Person at (132, 377): Move Left
# 1
# Closest Person at (130, 378): Move Left
# 1
# Closest Person at (131, 380): Move Left
# 1
# Closest Person at (129, 384): Move Left
# 1
# Closest Person at (127, 385): Move Left
# 1
# Closest Person at (125, 389): Move Left
# 1
# Closest Person at (125, 391): Move Left
# 1
# Closest Person at (121, 397): Move Left
# 1
# Closest Person at (122, 399): Move Left, Move Forward
# 1
# Closest Person at (120, 401): Move Left, Move Forward
# 1
# Closest Person at (119, 402): Move Left, Move Forward
# 1
# Closest Person at (119, 403): Move Left, Move Forward
# 1
# Closest Person at (119, 405): Move Left, Move Forward
# 1
# Closest Person at (114, 406): Move Left, Move Forward
# 1
# Closest Person at (117, 408): Move Left, Move Forward
# 1
# Closest Person at (97, 408): Move Left, Move Forward
# 1
# Closest Person at (104, 417): Move Left, Move Forward
# 1
# Closest Person at (106, 419): Move Left, Move Forward
# 1
# Closest Person at (100, 421): Move Left, Move Forward
# 1
# Closest Person at (104, 422): Move Left, Move Forward
# 1
# Closest Person at (104, 422): Move Left, Move Forward
# 1
# Closest Person at (105, 422): Move Left, Move Forward
# 1
# Closest Person at (106, 422): Move Left, Move Forward
# 1
# Closest Person at (105, 422): Move Left, Move Forward
# 1
# Closest Person at (96, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 426): Move Left, Move Forward
# 1
# Closest Person at (97, 426): Move Left, Move Forward
# 1
# Closest Person at (97, 425): Move Left, Move Forward
# 1
# Closest Person at (96, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 424): Move Left, Move Forward
# 1
# Closest Person at (98, 424): Move Left, Move Forward
# 1
# Closest Person at (96, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 424): Move Left, Move Forward
# 1
# Closest Person at (97, 424): Move Left, Move Forward
# 1
# Closest Person at (97, 424): Move Left, Move Forward
# 1
# Closest Person at (97, 424): Move Left, Move Forward
# 1
# Closest Person at (97, 424): Move Left, Move Forward
# 1
# Closest Person at (97, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 425): Move Left, Move Forward
# 1
# Closest Person at (96, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 425): Move Left, Move Forward
# 1
# Closest Person at (96, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 424): Move Left, Move Forward
# 1
# Closest Person at (97, 425): Move Left, Move Forward
# 1
# Closest Person at (98, 423): Move Left, Move Forward
# 1
# Closest Person at (101, 422): Move Left, Move Forward
# 1
# Closest Person at (102, 422): Move Left, Move Forward
# 1
# Closest Person at (102, 423): Move Left, Move Forward
# 1
# Closest Person at (100, 423): Move Left, Move Forward
# 1
# Closest Person at (101, 423): Move Left, Move Forward
# 1
# Closest Person at (98, 423): Move Left, Move Forward
# 1
# Closest Person at (103, 423): Move Left, Move Forward
# 1
# Closest Person at (103, 423): Move Left, Move Forward
# 1
# Closest Person at (102, 423): Move Left, Move Forward
# 1
# Closest Person at (101, 423): Move Left, Move Forward
# 1
# Closest Person at (100, 424): Move Left, Move Forward
# 1
# Closest Person at (99, 423): Move Left, Move Forward
# 1
# Closest Person at (100, 423): Move Left, Move Forward
# 1
# Closest Person at (100, 424): Move Left, Move Forward
# 1
# Closest Person at (100, 424): Move Left, Move Forward
# 1
# Closest Person at (98, 424): Move Left, Move Forward
# 1
# Closest Person at (97, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 424): Move Left, Move Forward
# 1
# Closest Person at (97, 425): Move Left, Move Forward
# 1
# Closest Person at (97, 426): Move Left, Move Forward
# 1
# Closest Person at (97, 426): Move Left, Move Forward
# 1
# Closest Person at (97, 426): Move Left, Move Forward
# 1
# Closest Person at (97, 426): Move Left, Move Forward
# 1
# Closest Person at (97, 428): Move Left, Move Forward
# 1
# Closest Person at (97, 428): Move Left, Move Forward
# 1
# Closest Person at (97, 429): Move Left, Move Forward
# 1
# Closest Person at (97, 429): Move Left, Move Forward
# 1
# Closest Person at (97, 429): Move Left, Move Forward
# 1
# Closest Person at (97, 430): Move Left, Move Forward
# 1
# Closest Person at (97, 429): Move Left, Move Forward
# 1
# Closest Person at (97, 430): Move Left, Move Forward
# 1
# Closest Person at (97, 430): Move Left, Move Forward
# 1
# Closest Person at (97, 430): Move Left, Move Forward
# 1
# Closest Person at (97, 430): Move Left, Move Forward
# 1
# Closest Person at (97, 430): Move Left, Move Forward
# 1
# Closest Person at (97, 430): Move Left, Move Forward
# 1
# Closest Person at (97, 430): Move Left, Move Forward
# 1
# Closest Person at (97, 430): Move Left, Move Forward
# 1
# Closest Person at (97, 430): Move Left, Move Forward
# 1
# Closest Person at (97, 430): Move Left, Move Forward
# 1
# Closest Person at (97, 430): Move Left, Move Forward
# 1
# Closest Person at (97, 430): Move Left, Move Forward
# 1
# Closest Person at (97, 430): Move Left, Move Forward
# 1
# Closest Person at (97, 430): Move Left, Move Forward
# 1
# Closest Person at (97, 430): Move Left, Move Forward
# 1
# Closest Person at (97, 430): Move Left, Move Forward
# 1
# Closest Person at (97, 429): Move Left, Move Forward
# 1
# Closest Person at (97, 429): Move Left, Move Forward
# 1
# Closest Person at (97, 428): Move Left, Move Forward
# 1
# Closest Person at (97, 427): Move Left, Move Forward
# 1
# Closest Person at (97, 424): Move Left, Move Forward
# 1
# Closest Person at (99, 421): Move Left, Move Forward
# 1
# Closest Person at (108, 418): Move Left, Move Forward
# 1
# Closest Person at (107, 407): Move Left, Move Forward
# 1
# Closest Person at (119, 405): Move Left, Move Forward
# 1
# Closest Person at (121, 404): Move Left, Move Forward
# 1
# Closest Person at (121, 403): Move Left, Move Forward
# 1
# Closest Person at (121, 401): Move Left, Move Forward
# 1
# Closest Person at (121, 399): Move Left, Move Forward
# 1
# Closest Person at (123, 397): Move Left
# 1
# Closest Person at (125, 395): Move Left
# 1
# Closest Person at (126, 391): Move Left
# 1
# Closest Person at (126, 392): Move Left
# 1
# Closest Person at (126, 393): Move Left
# 1
# Closest Person at (126, 392): Move Left
# 1
# Closest Person at (126, 392): Move Left
# 1
# Closest Person at (126, 392): Move Left
# 1
# Closest Person at (126, 391): Move Left
# 1
# Closest Person at (125, 390): Move Left
# 1
# Closest Person at (126, 390): Move Left
# 1
# Closest Person at (126, 390): Move Left
# 1
# Closest Person at (126, 390): Move Left
# 1
# Closest Person at (126, 390): Move Left
# 1
# Closest Person at (126, 390): Move Left
# 1
# Closest Person at (126, 390): Move Left
# 1
# Closest Person at (127, 389): Move Left
# 1
# Closest Person at (127, 389): Move Left
# 1
# Closest Person at (131, 384): Move Left
# 1
# Closest Person at (131, 381): Move Left
# 1
# Closest Person at (131, 379): Move Left
# 1
# Closest Person at (131, 378): Move Left
# 1
# Closest Person at (132, 378): Move Left
# 1
# Closest Person at (132, 376): Move Left
# 1
# Closest Person at (132, 376): Move Left
# 1
# Closest Person at (132, 375): Move Left
# 1
# Closest Person at (132, 374): Move Left
# 1
# Closest Person at (132, 375): Move Left
# 1
# Closest Person at (132, 374): Move Left
# 1
# Closest Person at (133, 373): Move Left
# 1
# Closest Person at (132, 374): Move Left
# 1
# Closest Person at (132, 374): Move Left
# 1
# Closest Person at (132, 373): Move Left
# 1
# Closest Person at (134, 371): Move Left
# 1
# Closest Person at (134, 370): Move Left
# 1
# Closest Person at (135, 370): Move Left
# 1
# Closest Person at (134, 368): Move Left
# 1
# Closest Person at (134, 369): Move Left
# 1
# Closest Person at (134, 369): Move Left
# 1
# Closest Person at (136, 369): Move Left
# 1
# Closest Person at (137, 369): Move Left
# 1
# Closest Person at (145, 364): Move Left
# 1
# Closest Person at (148, 364): Move Left
# 1
# Closest Person at (150, 363): Move Left
# 1
# Closest Person at (153, 364): Move Left
# 1
# Closest Person at (155, 366): Move Left
# 1
# Closest Person at (159, 367): Move Left
# 1
# Closest Person at (158, 366): Move Left
# 1
# Closest Person at (177, 363): Centered
# 1
# Closest Person at (179, 362): Centered
# 1
# Closest Person at (179, 365): Centered
# 1
# Closest Person at (179, 365): Centered
# 1
# Closest Person at (182, 365): Centered
# 1
# Closest Person at (186, 364): Centered
# 1
# Closest Person at (189, 365): Centered
# 1
# Closest Person at (181, 366): Centered
# 1
# Closest Person at (209, 367): Centered
# 1
# Closest Person at (219, 367): Centered
# 1
# Closest Person at (227, 367): Centered
# 1
# Closest Person at (233, 368): Centered
# 1
# Closest Person at (217, 367): Centered
# 1
# Closest Person at (217, 367): Centered
# 1
# Closest Person at (225, 366): Centered
# 1
# Closest Person at (228, 363): Centered
# 1
# Closest Person at (230, 362): Centered
# 1
# Closest Person at (233, 360): Centered
# 1
# Closest Person at (236, 359): Centered
# 1
# Closest Person at (237, 357): Centered
# 1
# Closest Person at (238, 359): Centered
# 1
# Closest Person at (237, 359): Centered
# 1
# Closest Person at (239, 357): Centered
# 1
# Closest Person at (239, 357): Centered
# 1
# Closest Person at (239, 356): Centered
# 1
# Closest Person at (238, 357): Centered
# 1
# Closest Person at (238, 357): Centered
# 1
# Closest Person at (239, 357): Centered
# 1
# Closest Person at (238, 357): Centered
# 1
# Closest Person at (239, 357): Centered
# 1
# Closest Person at (237, 358): Centered
# 1
# Closest Person at (237, 357): Centered
# 1
# Closest Person at (238, 356): Centered
# 1
# Closest Person at (238, 357): Centered
# 1
# Closest Person at (238, 357): Centered
# 1
# Closest Person at (238, 357): Centered
# 1
# Closest Person at (238, 357): Centered
# 1
# Closest Person at (239, 357): Centered
# 1
# Closest Person at (239, 358): Centered
# 1
# Closest Person at (238, 358): Centered
# 1
# Closest Person at (238, 358): Centered
# 1
# Closest Person at (239, 358): Centered
# 1
# Closest Person at (239, 357): Centered
# 1
# Closest Person at (238, 357): Centered
# 1
# Closest Person at (237, 359): Centered
# 1
# Closest Person at (238, 361): Centered
# 1
# Closest Person at (239, 363): Centered
# 1
# Closest Person at (240, 362): Centered
# 1
# Closest Person at (247, 362): Centered
# 1
# Closest Person at (246, 365): Centered
# 1
# Closest Person at (253, 365): Centered
# 1
# Closest Person at (261, 367): Centered
# 1
# Closest Person at (280, 370): Centered
# 1
# Closest Person at (275, 373): Centered
# 1
# Closest Person at (288, 375): Centered
# 1
# Closest Person at (300, 379): Centered
# 1
# Closest Person at (342, 382): Centered
# 1
# Closest Person at (351, 382): Centered
# 1
# Closest Person at (362, 382): Centered
# 1
# Closest Person at (364, 382): Centered
# 1
# Closest Person at (381, 382): Centered
# 1
# Closest Person at (392, 383): Centered
# 1
# Closest Person at (394, 383): Centered
# 1
# Closest Person at (405, 386): Centered
# 1
# Closest Person at (409, 386): Centered
# 1
# Closest Person at (415, 387): Centered
# 1
# Closest Person at (416, 388): Centered
# 1
# Closest Person at (415, 389): Centered
# 1
# Closest Person at (416, 388): Centered
# 1
# Closest Person at (420, 388): Centered
# 1
# Closest Person at (415, 388): Centered
# 1
# Closest Person at (428, 387): Centered
# 1
# Closest Person at (429, 385): Centered
# 1
# Closest Person at (430, 384): Centered
# 1
# Closest Person at (430, 384): Centered
# 1
# Closest Person at (430, 383): Centered
# 1
# Closest Person at (429, 384): Centered
# 1
# Closest Person at (429, 383): Centered
# 1
# Closest Person at (429, 382): Centered
# 1
# Closest Person at (428, 382): Centered
# 1
# Closest Person at (429, 382): Centered
# 1
# Closest Person at (431, 381): Centered
# 1
# Closest Person at (433, 380): Centered
# 1
# Closest Person at (432, 381): Centered
# 1
# Closest Person at (435, 380): Centered
# 1
# Closest Person at (437, 380): Centered
# 1
# Closest Person at (438, 379): Centered
# 1
# Closest Person at (436, 378): Centered
# 1
# Closest Person at (439, 377): Centered
# 1
# Closest Person at (443, 375): Centered
# 1
# Closest Person at (444, 375): Centered
# 1
# Closest Person at (443, 375): Centered
# 1
# Closest Person at (444, 374): Centered
# 1
# Closest Person at (445, 373): Centered
# 1
# Closest Person at (445, 372): Centered
# 1
# Closest Person at (446, 372): Centered
# 1
# Closest Person at (449, 369): Centered
# 1
# Closest Person at (452, 369): Centered
# 1
# Closest Person at (453, 369): Centered
# 1
# Closest Person at (453, 368): Centered
# 1
# Closest Person at (452, 368): Centered
# 1
# Closest Person at (452, 368): Centered
# 2
# Closest Person at (452, 366): Centered
# 1
# Closest Person at (452, 365): Centered
# 1
# Closest Person at (458, 361): Centered
# 2
# Closest Person at (458, 359): Centered
# 1
# Closest Person at (459, 360): Centered
# 2
# Closest Person at (459, 361): Centered
# 2
# Closest Person at (458, 361): Centered
# 1
# Closest Person at (458, 359): Centered
# 2
# Closest Person at (459, 360): Centered
# 2
# Closest Person at (459, 359): Centered
# 2
# Closest Person at (459, 360): Centered
# 2
# Closest Person at (457, 360): Centered
# 2
# Closest Person at (458, 359): Centered
# 2
# Closest Person at (458, 359): Centered
# 2
# Closest Person at (458, 359): Centered
# 2
# Closest Person at (458, 359): Centered
# 2
# Closest Person at (459, 359): Centered
# 2
# Closest Person at (457, 359): Centered
# 2
# Closest Person at (457, 359): Centered
# 2
# Closest Person at (458, 360): Centered
# 2
# Closest Person at (458, 359): Centered
# 2
# Closest Person at (458, 358): Centered
# 2
# Closest Person at (458, 359): Centered
# 2
# Closest Person at (458, 358): Centered
# 2
# Closest Person at (459, 359): Centered
# 2
# Closest Person at (459, 359): Centered
# 2
# Closest Person at (459, 359): Centered
# 2
# Closest Person at (459, 359): Centered
# 2
# Closest Person at (459, 359): Centered
# 2
# Closest Person at (460, 359): Centered
# 2
# Closest Person at (459, 359): Centered
# 2
# Closest Person at (460, 359): Centered
# 2
# Closest Person at (460, 359): Centered
# 2
# Closest Person at (460, 359): Centered
# 2
# Closest Person at (460, 359): Centered
# 2
# Closest Person at (460, 358): Centered
# 2
# Closest Person at (460, 359): Centered
# 2
# Closest Person at (460, 359): Centered
# 2
# Closest Person at (460, 359): Centered
# 2
# Closest Person at (460, 359): Centered
# 2
# Closest Person at (460, 359): Centered
# 2
# Closest Person at (461, 359): Centered
# 2
# Closest Person at (460, 359): Centered
# 2
# Closest Person at (461, 359): Centered
# 2
# Closest Person at (461, 359): Centered
# 2
# Closest Person at (461, 359): Centered
# 2
# Closest Person at (461, 358): Centered
# 2
# Closest Person at (461, 359): Centered
# 2
# Closest Person at (461, 359): Centered
# 2
# Closest Person at (461, 358): Centered
# 2
# Closest Person at (461, 359): Centered
# 2
# Closest Person at (461, 359): Centered
# 2
# Closest Person at (461, 357): Centered
# 2
# Closest Person at (461, 359): Centered
# 2
# Closest Person at (461, 359): Centered
# 2
# Closest Person at (461, 358): Centered
# 2
# Closest Person at (461, 359): Centered
# 2
# Closest Person at (460, 358): Centered
# 2
# Closest Person at (460, 359): Centered
# 2
# Closest Person at (461, 358): Centered
# 2
# Closest Person at (460, 358): Centered
# 2
# Closest Person at (459, 359): Centered
# 2
# Closest Person at (459, 358): Centered
# 2
# Closest Person at (461, 358): Centered
# 2
# Closest Person at (463, 358): Centered
# 2
# Closest Person at (464, 356): Centered
# 2
# Closest Person at (465, 357): Centered
# 2
# Closest Person at (465, 357): Centered
# 2
# Closest Person at (464, 356): Centered
# 2
# Closest Person at (465, 357): Centered
# 2
# Closest Person at (465, 357): Centered
# 2
# Closest Person at (468, 357): Centered
# 2
# Closest Person at (469, 357): Centered
# 2
# Closest Person at (468, 356): Centered
# 2
# Closest Person at (470, 356): Centered
# 2
# Closest Person at (473, 355): Centered
# 2
# Closest Person at (473, 355): Centered
# 2
# Closest Person at (476, 355): Centered
# 2
# Closest Person at (479, 355): Centered
# 2
# Closest Person at (479, 355): Move Right
# 2
# Closest Person at (485, 357): Move Right
# 2
# Closest Person at (485, 357): Move Right
# 2
# Closest Person at (485, 357): Move Right
# 2
# Closest Person at (486, 357): Move Right
# 2
# Closest Person at (486, 357): Move Right
# 2
# Closest Person at (156, 359): Move Left, Move Forward
# 2
# Closest Person at (157, 360): Move Left, Move Forward
# 2
# Closest Person at (497, 357): Move Right
# 2
# Closest Person at (162, 361): Move Left, Move Forward
# 2
# Closest Person at (164, 360): Move Left, Move Forward
# 2
# Closest Person at (166, 359): Move Left, Move Forward
# 2
# Closest Person at (170, 360): Move Left, Move Forward
# 2
# Closest Person at (172, 359): Move Left, Move Forward
# 2
# Closest Person at (179, 359): Move Left, Move Forward
# 2
# Closest Person at (182, 360): Move Left, Move Forward
# 2
# Closest Person at (183, 358): Move Left, Move Forward
# 2
# Closest Person at (186, 360): Move Left, Move Forward
# 2
# Closest Person at (199, 366): Move Left, Move Forward
# 2
# Closest Person at (184, 360): Move Left, Move Forward
# 2
# Closest Person at (184, 359): Move Left, Move Forward
# 2
# Closest Person at (183, 364): Move Left, Move Forward
# 2
# Closest Person at (184, 370): Move Left, Move Forward
# 2
# Closest Person at (184, 371): Move Left, Move Forward
# 2
# Closest Person at (185, 361): Move Left, Move Forward
# 2
# Closest Person at (185, 363): Move Left, Move Forward
# 2
# Closest Person at (183, 371): Move Left, Move Forward
# 2
# Closest Person at (183, 363): Move Left, Move Forward
# 2
# Closest Person at (182, 360): Move Left, Move Forward
# 2
# Closest Person at (183, 374): Move Left, Move Forward
# 2
# Closest Person at (182, 364): Move Left, Move Forward
# 2
# Closest Person at (182, 359): Move Left, Move Forward
# 2
# Closest Person at (182, 359): Move Left, Move Forward
# 2
# Closest Person at (182, 361): Move Left, Move Forward
# 2
# Closest Person at (183, 361): Move Left, Move Forward
# 2
# Closest Person at (183, 370): Move Left, Move Forward
# 2
# Closest Person at (182, 367): Move Left, Move Forward
# 2
# Closest Person at (182, 364): Move Left, Move Forward
# 2
# Closest Person at (182, 371): Move Left, Move Forward
# 2
# Closest Person at (182, 366): Move Left, Move Forward
# 2
# Closest Person at (183, 361): Move Left, Move Forward
# 2
# Closest Person at (182, 359): Move Left, Move Forward
# 2
# Closest Person at (182, 360): Move Left, Move Forward
# 2
# Closest Person at (183, 360): Move Left, Move Forward
# 2
# Closest Person at (182, 360): Move Left, Move Forward
# 2
# Closest Person at (182, 360): Move Left, Move Forward
# 2
# Closest Person at (183, 359): Move Left, Move Forward
# 2
# Closest Person at (182, 360): Move Left, Move Forward
# 2
# Closest Person at (182, 360): Move Left, Move Forward
# 2
# Closest Person at (183, 363): Move Left, Move Forward
# 2
# Closest Person at (183, 359): Move Left, Move Forward
# 1
# Closest Person at (183, 360): Move Left, Move Forward
# 1
# Closest Person at (576, 466): Move Right, Move Forward
# 2
# Closest Person at (182, 364): Move Left, Move Forward
# 2
# Closest Person at (182, 360): Move Left, Move Forward
# 2
# Closest Person at (182, 361): Move Left, Move Forward
# 2
# Closest Person at (182, 367): Move Left, Move Forward
# 2
# Closest Person at (183, 359): Move Left, Move Forward
# 2
# Closest Person at (183, 364): Move Left, Move Forward
# 2
# Closest Person at (183, 360): Move Left, Move Forward
# 2
# Closest Person at (182, 364): Move Left, Move Forward
# 2
# Closest Person at (182, 358): Move Left, Move Forward
# 2
# Closest Person at (182, 358): Move Left, Move Forward
# 2
# Closest Person at (182, 358): Move Left, Move Forward
# 2
# Closest Person at (183, 358): Move Left, Move Forward
# 2
# Closest Person at (182, 358): Move Left, Move Forward
# 2
# Closest Person at (182, 360): Move Left, Move Forward
# 2
# Closest Person at (182, 359): Move Left, Move Forward
# 2
# Closest Person at (183, 359): Move Left, Move Forward
# 2
# Closest Person at (182, 360): Move Left, Move Forward
# 2
# Closest Person at (182, 363): Move Left, Move Forward
# 2
# Closest Person at (182, 358): Move Left, Move Forward
# 2
# Closest Person at (182, 359): Move Left, Move Forward
# 2
# Closest Person at (183, 360): Move Left, Move Forward
# 2
# Closest Person at (182, 357): Move Left, Move Forward
# 2
# Closest Person at (183, 374): Move Left, Move Forward
# 2
# Closest Person at (183, 359): Move Left, Move Forward
# 2
# Closest Person at (183, 359): Move Left, Move Forward
# 2
# Closest Person at (182, 359): Move Left, Move Forward
# 2
# Closest Person at (182, 358): Move Left, Move Forward
# 2
# Closest Person at (183, 359): Move Left, Move Forward
# 2
# Closest Person at (182, 359): Move Left, Move Forward
# 2
# Closest Person at (182, 360): Move Left, Move Forward
# 2
# Closest Person at (183, 360): Move Left, Move Forward
# 2
# Closest Person at (182, 362): Move Left, Move Forward
# 2
# Closest Person at (185, 360): Move Left, Move Forward
# 2
# Closest Person at (188, 360): Move Left, Move Forward
# 2
# Closest Person at (194, 380): Move Left, Move Forward
# 2
# Closest Person at (198, 370): Move Left, Move Forward
# 2
# Closest Person at (203, 382): Move Left, Move Forward
# 2
# Closest Person at (202, 364): Move Left, Move Forward
# 2
# Closest Person at (205, 383): Move Left, Move Forward
# 2
# Closest Person at (206, 368): Move Left, Move Forward
# 2
# Closest Person at (207, 371): Move Left, Move Forward
# 2
# Closest Person at (209, 362): Move Left, Move Forward
# 2
# Closest Person at (214, 375): Move Left, Move Forward
# 2
# Closest Person at (215, 355): Move Left, Move Forward
# 2
# Closest Person at (218, 358): Move Left, Move Forward
# 2
# Closest Person at (218, 363): Move Left, Move Forward
# 2
# Closest Person at (221, 378): Move Left, Move Forward
# 2
# Closest Person at (221, 362): Move Left, Move Forward
# 2
# Closest Person at (223, 376): Move Left, Move Forward
# 1
# Closest Person at (601, 472): Move Right, Move Forward
# 2
# Closest Person at (234, 369): Move Left, Move Forward
# 2
# Closest Person at (235, 375): Move Left, Move Forward
# 2
# Closest Person at (238, 380): Move Left, Move Forward
# 2
# Closest Person at (238, 365): Move Left, Move Forward
# 2
# Closest Person at (238, 368): Move Left, Move Forward
# 2
# Closest Person at (243, 379): Move Left, Move Forward
# 1
# Closest Person at (245, 372): Move Left, Move Forward
# 1
# Closest Person at (246, 381): Move Left, Move Forward
# 1
# Closest Person at (249, 388): Move Left, Move Forward
# 0
# No humans detected.
# 1
# Closest Person at (252, 387): Move Left, Move Forward
# 1
# Closest Person at (250, 384): Move Left, Move Forward
# 1
# Closest Person at (253, 388): Move Left, Move Forward
# 1
# Closest Person at (258, 386): Move Left, Move Forward
# 1
# Closest Person at (258, 372): Move Left, Move Forward
# 1
# Closest Person at (260, 381): Move Left, Move Forward
# 1
# Closest Person at (261, 386): Move Left, Move Forward
# 1
# Closest Person at (262, 379): Move Left, Move Forward
# 1
# Closest Person at (263, 378): Move Left, Move Forward
# 1
# Closest Person at (264, 382): Move Left, Move Forward
# 1
# Closest Person at (268, 373): Move Left, Move Forward
# 1
# Closest Person at (271, 388): Move Forward
# 1
# Closest Person at (269, 384): Move Left, Move Forward
# 1
# Closest Person at (270, 374): Move Left, Move Forward
# 1
# Closest Person at (272, 384): Move Left, Move Forward
# 1
# Closest Person at (274, 373): Move Forward
# 1
# Closest Person at (274, 383): Move Forward
# 1
# Closest Person at (280, 375): Move Forward
# 1
# Closest Person at (287, 394): Move Forward
# 0
# No humans detected.
# 1
# Closest Person at (285, 388): Move Forward
# 1
# Closest Person at (285, 390): Move Forward
# 1
# Closest Person at (285, 391): Move Forward
# 1
# Closest Person at (286, 391): Move Forward
# 1
# Closest Person at (286, 391): Move Forward
# 1
# Closest Person at (287, 391): Move Forward
# 1
# Closest Person at (284, 373): Move Forward
# 1
# Closest Person at (286, 390): Move Forward
# 1
# Closest Person at (286, 390): Move Forward
# 1
# Closest Person at (287, 390): Move Forward
# 1
# ...
# 2
# Closest Person at (280, 323): Move Forward
# 2
# Closest Person at (281, 325): Move Forward
# 2
# Closest Person at (280, 327): Move Forward
# 2
# Closest Person at (281, 326): Move Forward
# 2
# Closest Person at (281, 324): Move Forward
# 2
# Closest Person at (281, 325): Move Forward
# 2
# Closest Person at (281, 327): Move Forward
# 2
# Closest Person at (280, 325): Move Forward
# 2
# Closest Person at (281, 326): Move Forward
# 2
# Closest Person at (280, 326): Move Forward
# 2
# Closest Person at (279, 326): Move Forward
# 2
# Closest Person at (281, 328): Move Forward
# 2
# Closest Person at (280, 328): Move Forward
# 2
# Closest Person at (282, 329): Move Forward
# 2
# Closest Person at (281, 325): Move Forward
# 2
# Closest Person at (281, 330): Move Forward
# 2
# Closest Person at (278, 341): Move Forward
# 2
# Closest Person at (278, 339): Move Forward
# 2
# Closest Person at (278, 346): Move Forward
# 2
# Closest Person at (279, 340): Move Forward
# 2
# Closest Person at (280, 342): Move Forward
# 2
# Closest Person at (282, 345): Move Forward
# 2
# Closest Person at (280, 343): Move Forward
# 2
# Closest Person at (278, 341): Move Forward
# 2
# Closest Person at (279, 345): Move Forward
# 2
# Closest Person at (279, 345): Move Forward
# 2
# Closest Person at (278, 346): Move Forward
# 2
# Closest Person at (279, 346): Move Forward
# 2
# Closest Person at (278, 347): Move Forward
# 2
# Closest Person at (277, 348): Move Forward
# 1
# Closest Person at (278, 346): Move Forward
# 2
# Closest Person at (275, 345): Move Forward
# 1
# Closest Person at (273, 346): Move Forward
# 1
# Closest Person at (266, 349): Move Left, Move Forward
# 1
# Closest Person at (267, 361): Move Left, Move Forward
# 1
# Closest Person at (262, 358): Move Left, Move Forward
# 1
# Closest Person at (261, 343): Move Left, Move Forward
# 1
# Closest Person at (259, 342): Move Left, Move Forward
# 1
# Closest Person at (257, 341): Move Left, Move Forward
# 1
# Closest Person at (256, 358): Move Left, Move Forward
# 2
# Closest Person at (250, 354): Move Left, Move Forward
# 2
# Closest Person at (249, 362): Move Left, Move Forward
# 2
# Closest Person at (249, 362): Move Left, Move Forward
# 1
# Closest Person at (248, 363): Move Left, Move Forward
# 2
# Closest Person at (247, 362): Move Left, Move Forward
# 2
# Closest Person at (246, 362): Move Left, Move Forward
# 2
# Closest Person at (246, 363): Move Left, Move Forward
# 2
# Closest Person at (244, 359): Move Left, Move Forward
# 2
# Closest Person at (245, 354): Move Left, Move Forward
# 2
# Closest Person at (246, 358): Move Left, Move Forward
# 2
# Closest Person at (246, 361): Move Left, Move Forward
# 2
# Closest Person at (246, 361): Move Left, Move Forward
# 2
# Closest Person at (246, 362): Move Left, Move Forward
# 2
# Closest Person at (246, 362): Move Left, Move Forward
# 2
# Closest Person at (246, 363): Move Left, Move Forward
# 2
# Closest Person at (245, 361): Move Left, Move Forward
# 2
# Closest Person at (245, 364): Move Left, Move Forward
# 2
# Closest Person at (246, 365): Move Left, Move Forward
# 2
# Closest Person at (246, 364): Move Left, Move Forward
# 2
# Closest Person at (246, 365): Move Left, Move Forward
# 2
# Closest Person at (246, 363): Move Left, Move Forward
# 2
# Closest Person at (247, 365): Move Left, Move Forward
# 2
# Closest Person at (248, 368): Move Left, Move Forward
# 1
# Closest Person at (262, 370): Move Left, Move Forward
# 1
# Closest Person at (264, 364): Move Left, Move Forward
# 1
# Closest Person at (266, 366): Move Left, Move Forward
# 1
# Closest Person at (266, 368): Move Left, Move Forward
# 1
# Closest Person at (266, 368): Move Left, Move Forward
# 1
# Closest Person at (268, 369): Move Left, Move Forward
# 1
# Closest Person at (270, 372): Move Left, Move Forward
# 1
# Closest Person at (277, 367): Move Forward
# 1
# Closest Person at (277, 366): Move Forward
# 1
# Closest Person at (278, 366): Move Forward
# 1
# Closest Person at (280, 366): Move Forward
# 1
# Closest Person at (279, 366): Move Forward
# 1
# Closest Person at (279, 366): Move Forward
# 1
# Closest Person at (280, 365): Move Forward
# 1
# Closest Person at (284, 368): Move Forward
# 1
# Closest Person at (284, 367): Move Forward
# 1
# Closest Person at (285, 366): Move Forward
# 1
# Closest Person at (284, 365): Move Forward
# 1
# Closest Person at (284, 365): Move Forward
# 1
# Closest Person at (286, 366): Move Forward
# 1
# Closest Person at (283, 361): Move Forward
# 1
# Closest Person at (285, 366): Move Forward
# 1
# Closest Person at (285, 368): Move Forward
# 1
# Closest Person at (286, 367): Move Forward
# 1
# Closest Person at (283, 364): Move Forward
# 1
# Closest Person at (284, 363): Move Forward
# 1
# Closest Person at (284, 364): Move Forward
# 1
# Closest Person at (282, 364): Move Forward
# 1
# Closest Person at (283, 364): Move Forward
# 1
# Closest Person at (284, 363): Move Forward
# 1
# Closest Person at (282, 362): Move Forward
# 1
# Closest Person at (284, 363): Move Forward
# 1
# Closest Person at (284, 362): Move Forward
# 1
# Closest Person at (286, 364): Move Forward
# 1
# Closest Person at (284, 364): Move Forward
# 1
# Closest Person at (285, 363): Move Forward
# 1
# Closest Person at (284, 365): Move Forward
# 1
# Closest Person at (285, 365): Move Forward
# 1
# Closest Person at (285, 364): Move Forward
# 1
# Closest Person at (286, 364): Move Forward
# 1
# Closest Person at (285, 366): Move Forward
# 1
# Closest Person at (286, 364): Move Forward
# 1
# Closest Person at (287, 365): Move Forward
# 1
# Closest Person at (289, 368): Move Forward
# 1
# Closest Person at (285, 363): Move Forward
# 1
# Closest Person at (284, 364): Move Forward
# 1
# Closest Person at (284, 364): Move Forward
# 1
# Closest Person at (285, 364): Move Forward
# 1
# Closest Person at (282, 364): Move Forward
# 1
# Closest Person at (282, 363): Move Forward
# 1
# Closest Person at (285, 365): Move Forward
# 1
# Closest Person at (282, 363): Move Forward
# 1
# Closest Person at (281, 363): Move Forward
# 1
# Closest Person at (283, 363): Move Forward
# 1
# Closest Person at (281, 365): Move Forward
# 1
# Closest Person at (284, 366): Move Forward
# 1
# Closest Person at (284, 365): Move Forward
# 1
# Closest Person at (281, 366): Move Forward
# 1
# Closest Person at (284, 365): Move Forward
# 1
# Closest Person at (281, 368): Move Forward
# 1
# Closest Person at (280, 367): Move Forward
# 1
# Closest Person at (280, 368): Move Forward
# 1
# Closest Person at (279, 366): Move Forward
# 1
# Closest Person at (280, 366): Move Forward
# 1
# Closest Person at (279, 364): Move Forward
# 1
# Closest Person at (283, 364): Move Forward
# 1
# Closest Person at (283, 366): Move Forward
# 1
# Closest Person at (282, 365): Move Forward
# 1
# Closest Person at (283, 364): Move Forward
# 1
# Closest Person at (287, 364): Move Forward
# 1
# Closest Person at (283, 361): Move Forward
# 1
# Closest Person at (291, 360): Move Forward
# 1
# Closest Person at (284, 362): Move Forward
# 1
# Closest Person at (286, 358): Move Forward
# 2
# Closest Person at (285, 354): Move Forward
# 1
# Closest Person at (281, 348): Move Forward
# 1
# Closest Person at (281, 354): Move Forward
# 1
# Closest Person at (569, 496): Move Right, Move Forward
# 2
# Closest Person at (284, 349): Move Forward
# 2
# Closest Person at (282, 348): Move Forward
# 1
# Closest Person at (284, 349): Move Forward
# 2
# Closest Person at (284, 348): Move Forward
# 2
# Closest Person at (284, 347): Move Forward
# 2
# Closest Person at (285, 346): Move Forward
# 2
# Closest Person at (281, 346): Move Forward
# 2
# Closest Person at (286, 343): Move Forward
# 2
# Closest Person at (284, 343): Move Forward
# 2
# Closest Person at (284, 345): Move Forward
# 2
# Closest Person at (281, 342): Move Forward
# 2
# Closest Person at (282, 342): Move Forward
# 2
# Closest Person at (284, 343): Move Forward
# 2
# Closest Person at (283, 340): Move Forward
# 2
# Closest Person at (286, 340): Move Forward
# 2
# Closest Person at (285, 340): Move Forward
# 2
# Closest Person at (288, 340): Move Forward
# 2
# Closest Person at (286, 340): Move Forward
# 2
# Closest Person at (284, 339): Move Forward
# 2
# Closest Person at (283, 338): Move Forward
# 2
# Closest Person at (281, 338): Move Forward
# 2
# Closest Person at (281, 337): Move Forward
# 2
# Closest Person at (283, 341): Move Forward
# 2
# Closest Person at (283, 338): Move Forward
# 2
# Closest Person at (285, 340): Move Forward
# 2
# Closest Person at (284, 336): Move Forward
# 2
# Closest Person at (284, 338): Move Forward
# 2
# Closest Person at (285, 337): Move Forward
# 2
# Closest Person at (283, 334): Move Forward
# 2
# Closest Person at (287, 332): Move Forward
# 2
# Closest Person at (281, 331): Move Forward
# 2
# Closest Person at (285, 330): Move Forward
# 2
# Closest Person at (285, 331): Move Forward
# 2
# Closest Person at (289, 330): Move Forward
# 2
# Closest Person at (286, 327): Move Forward
# 2
# Closest Person at (285, 324): Move Forward
# 2
# Closest Person at (286, 325): Move Forward
# 2
# Closest Person at (283, 316): Centered
# 2
# Closest Person at (282, 312): Centered
# 2
# Closest Person at (283, 313): Centered
# 2
# Closest Person at (284, 312): Centered
# 2
# Closest Person at (283, 311): Centered
# 2
# Closest Person at (283, 311): Centered
# 2
# Closest Person at (284, 313): Centered
# 2
# Closest Person at (283, 310): Centered
# 2
# Closest Person at (284, 307): Centered
# 2
# Closest Person at (284, 307): Centered
# 2
# Closest Person at (283, 305): Centered
# 2
# Closest Person at (283, 306): Centered
# 2
# Closest Person at (283, 307): Centered
# 2
# Closest Person at (284, 307): Centered
# 2
# Closest Person at (284, 307): Centered
# 2
# Closest Person at (284, 310): Centered
# 2
# Closest Person at (284, 306): Centered
# 2
# Closest Person at (284, 307): Centered
# 2
# Closest Person at (283, 309): Centered
# 2
# Closest Person at (283, 310): Centered
# 2
# Closest Person at (281, 310): Centered
# 2
# Closest Person at (279, 309): Centered
# 2
# Closest Person at (280, 310): Centered
# 2
# Closest Person at (283, 311): Centered
# 2
# Closest Person at (284, 311): Centered
# 2
# Closest Person at (284, 312): Centered
# 2
# Closest Person at (284, 313): Centered
# 2
# Closest Person at (282, 311): Centered
# 2
# Closest Person at (283, 312): Centered
# 2
# Closest Person at (283, 311): Centered
# 2
# Closest Person at (282, 310): Centered
# 2
# Closest Person at (283, 310): Centered
# 2
# Closest Person at (288, 312): Centered
# 2
# Closest Person at (288, 312): Centered
# 2
# Closest Person at (285, 310): Centered
# 2
# Closest Person at (283, 311): Centered
# 2
# Closest Person at (285, 309): Centered
# 2
# Closest Person at (283, 309): Centered
# 2
# Closest Person at (288, 310): Centered
# 2
# Closest Person at (290, 312): Centered
# 2
# Closest Person at (283, 313): Centered
# 2
# Closest Person at (282, 311): Centered
# 2
# Closest Person at (282, 313): Centered
# 2
# Closest Person at (281, 313): Move Forward
# 2
# Closest Person at (282, 321): Move Forward
# 2
# Closest Person at (278, 325): Move Forward
# 2
# Closest Person at (269, 331): Move Left, Move Forward
# 2
# Closest Person at (266, 329): Move Left, Move Forward
# 2
# Closest Person at (265, 335): Move Left, Move Forward
# 2
# Closest Person at (260, 335): Move Left, Move Forward
# 1
# Closest Person at (256, 332): Move Left, Move Forward
# 2
# Closest Person at (249, 333): Move Left, Move Forward
# 1
# Closest Person at (233, 303): Move Left, Move Forward
# 2
# Closest Person at (226, 308): Move Left, Move Forward
# 2
# Closest Person at (189, 315): Move Left, Move Forward
# 1
# Closest Person at (523, 458): Move Right, Move Forward
# 1
# Closest Person at (525, 370): Move Right
# 1
# Closest Person at (524, 367): Move Right
# 2
# Closest Person at (148, 334): Move Left, Move Forward
# 2
# Closest Person at (137, 333): Move Left, Move Forward
# 2
# Closest Person at (130, 336): Move Left, Move Forward
# 2
# Closest Person at (503, 358): Move Right
# 1
# Closest Person at (504, 359): Move Right
# 2
# Closest Person at (511, 361): Move Right
# 2
# Closest Person at (503, 363): Move Right
# 1
# Closest Person at (507, 367): Move Right
# 1
# Closest Person at (504, 369): Move Right
# 1
# Closest Person at (500, 370): Move Right
# 1
# Closest Person at (496, 369): Move Right
# 1
# Closest Person at (479, 368): Centered
# 1
# Closest Person at (475, 367): Centered
# 1
# Closest Person at (470, 366): Centered
# 1
# Closest Person at (465, 366): Centered
# 1
# Closest Person at (460, 366): Centered
# 1
# Closest Person at (456, 365): Centered
# 1
# Closest Person at (451, 363): Centered
# 1
# Closest Person at (449, 361): Centered
# 1
# Closest Person at (437, 360): Centered
# 1
# Closest Person at (435, 360): Centered
# 1
# Closest Person at (433, 361): Centered
# 1
# Closest Person at (429, 361): Centered
# 1
# Closest Person at (426, 361): Centered
# 1
# Closest Person at (425, 361): Centered
# 1
# Closest Person at (421, 361): Centered
# 1
# Closest Person at (413, 361): Centered
# 1
# Closest Person at (411, 362): Centered
# 1
# Closest Person at (410, 362): Centered
# 1
# Closest Person at (408, 362): Centered
# 1
# Closest Person at (405, 362): Centered
# 1
# Closest Person at (403, 362): Centered
# 1
# Closest Person at (402, 362): Centered
# 1
# Closest Person at (402, 362): Centered
# 1
# Closest Person at (400, 363): Centered
# 1
# Closest Person at (399, 362): Centered
# 1
# Closest Person at (399, 362): Centered
# 1
# Closest Person at (398, 363): Centered
# 1
# Closest Person at (397, 363): Centered
# 1
# Closest Person at (397, 362): Centered
# 1
# Closest Person at (396, 362): Centered
# 1
# Closest Person at (396, 363): Centered
# 1
# Closest Person at (393, 363): Centered
# 1
# Closest Person at (393, 362): Centered
# 1
# Closest Person at (392, 361): Centered
# 1
# Closest Person at (391, 362): Centered
# 1
# Closest Person at (390, 362): Centered
# 1
# Closest Person at (388, 362): Centered
# 1
# Closest Person at (388, 362): Centered
# 1
# Closest Person at (386, 363): Centered
# 1
# Closest Person at (385, 363): Centered
# 1
# Closest Person at (386, 363): Centered
# 1
# Closest Person at (383, 363): Centered
# 1
# Closest Person at (383, 363): Centered
# 1
# Closest Person at (382, 363): Centered
# 1
# Closest Person at (382, 364): Centered
# 1
# Closest Person at (382, 363): Centered
# 1
# Closest Person at (381, 363): Centered
# 1
# Closest Person at (382, 362): Centered
# 1
# Closest Person at (382, 363): Centered
# 1
# Closest Person at (382, 363): Centered
# 1
# Closest Person at (381, 364): Centered
# 1
# Closest Person at (382, 364): Centered
# 1
# Closest Person at (383, 364): Centered
# 1
# Closest Person at (383, 364): Centered
# 1
# Closest Person at (383, 364): Centered
# 1
# Closest Person at (382, 364): Centered
# 1
# Closest Person at (382, 363): Centered
# 1
# Closest Person at (384, 364): Centered
# 1
# Closest Person at (384, 364): Centered
# 1
# Closest Person at (384, 364): Centered
# 1
# Closest Person at (384, 364): Centered
# 1
# Closest Person at (384, 364): Centered
# 1
# Closest Person at (385, 364): Centered
# 1
# Closest Person at (383, 364): Centered
# 1
# Closest Person at (346, 364): Centered
# 1
# Closest Person at (373, 363): Centered
# 1
# Closest Person at (381, 363): Centered
# 1
# Closest Person at (378, 363): Centered
# 1
# Closest Person at (379, 363): Centered
# 1
# Closest Person at (377, 362): Centered
# 1
# Closest Person at (377, 362): Centered
# 1
# Closest Person at (373, 362): Centered
# 1
# Closest Person at (374, 362): Centered
# 1
# Closest Person at (374, 363): Centered
# 1
# Closest Person at (370, 363): Centered
# 1
# Closest Person at (377, 363): Centered
# 1
# Closest Person at (330, 364): Centered
# 1
# Closest Person at (331, 364): Centered
# 1
# Closest Person at (329, 363): Centered
# 1
# Closest Person at (370, 364): Centered
# 1
# Closest Person at (372, 364): Centered
# 1
# Closest Person at (371, 364): Centered
# 1
# Closest Person at (372, 364): Centered
# 1
# Closest Person at (374, 364): Centered
# 1
# Closest Person at (375, 364): Centered
# 1
# Closest Person at (376, 364): Centered
# 1
# Closest Person at (380, 364): Centered
# 1
# Closest Person at (381, 364): Centered
# 1
# Closest Person at (382, 364): Centered
# 1
# Closest Person at (382, 365): Centered
# 1
# Closest Person at (382, 364): Centered
# 1
# Closest Person at (382, 364): Centered
# 1
# Closest Person at (381, 364): Centered
# 1
# Closest Person at (380, 364): Centered
# 1
# Closest Person at (379, 364): Centered
# 1
# Closest Person at (378, 364): Centered
# 1
# Closest Person at (379, 364): Centered
# 1
# Closest Person at (378, 363): Centered
# 1
# Closest Person at (378, 364): Centered
# 1
# Closest Person at (378, 364): Centered
# 1
# Closest Person at (378, 364): Centered
# 1
# Closest Person at (378, 364): Centered
# 1
# Closest Person at (378, 364): Centered
# 1
# Closest Person at (378, 364): Centered
# 1
# Closest Person at (379, 363): Centered
# 1
# Closest Person at (378, 364): Centered
# 1
# Closest Person at (379, 364): Centered
# 1
# Closest Person at (379, 364): Centered
# 1
# Closest Person at (378, 364): Centered
# Exiting live feed
